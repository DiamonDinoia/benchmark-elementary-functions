# %%
import matplotlib.pyplot as plt


y = [65.5, 50.7, 46.8, 2.5, 1.1] 
x = list(range(len(y)))

plt.bar(x, y)
plt.xticks(x, ['log', 'logf', 'fast', 'approx', 'faster'])

plt.xlabel('Implementation')
plt.ylabel('Time (microseconds)')
plt.title('Time to compute log')
plt.savefig('log.svg')
plt.show()
